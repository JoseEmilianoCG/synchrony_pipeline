# %%
import os
from src.C1.data_loader import dataloader
from src.C4.train_ml_models import run_ml
from src.C3.hyperparameter_search import hyperparameter_search, evaluar_modelo_final

from src.visualization.viz import generate_report 

def main():
    cwd = os.getcwd()

    ### ============= 1. DATA LOADING (C1) ============= ###
    print("Cargando datos (C1)...")
    feat_mat, stats_report = dataloader(cwd=cwd)

    ### ============= 2. MACHINE LEARNING (C4) ============= ###
    print("\nEntrenando modelos ml (C4)...")
    dict_ml, X_train, y_train, X_test, y_test = run_ml(feat_mat, cwd)

    ### ============= 3. MODEL OPTIMIZATION (C3) ============= ###
    print("\nIniciando optimización (C3)...")
    dict_opt = hyperparameter_search(X_train, y_train, dict_ml, dict_ml['bounds_recomendados'])

    ### ============= 4. EVALUACIÓN FINAL ============= ###
    evaluar_modelo_final(dict_opt['modelo_optimizado'], X_test, y_test, dict_ml['accuracy'], cwd)

    ### ============= 5. VISUALIZATION Y REPORTE (C6) ============= ###
    print("\nGenerando reporte (C6)...")
    generate_report() 

if __name__ == "__main__":
    main()
# Out:
# Cargando datos (C1)...
#
# Entrenando modelos ml (C4)...
#
# === COMPARE THE MODELS ===
# Modelo                 Accuracy  Precision
# ------------------------------------------
# RandomForest             0.6877     0.6880
# SVM                      0.6387     0.6384
# GradientBoosting         0.6821     0.6819
#
#  Best model: RandomForest (Accuracy: 0.6877)
#  RandomForest_model.pkl guardado
#  SVM_model.pkl guardado
#  GradientBoosting_model.pkl guardado
#
# Iniciando optimización (C3)...
# Mejores hiperparámetros: {'n_estimators': 197, 'max_depth': 10}
#
# === VALIDACIÓN FINAL EN DATOS NO VISTOS ===
# Accuracy final: 0.6905
# F1 Macro: 0.6886
# F1 Weighted: 0.6894
# Mejora accuracy: +0.28%
#
# Generando reporte (C6)...
# C6 ejecutado correctamente.
# Reporte LaTeX: reports\final_report.tex
# Tabla comparativa: reports\model_comparison.csv
# Figuras generadas en: reports\figures
